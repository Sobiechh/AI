# %%
import numpy as np

# %%
X = np.array(([2, 9], [1, 5], [3, 6]), dtype=float)
y = np.array(([92], [86], [89]), dtype=float)

X = X/np.amax(X, axis=0) 
y = y/100

# %%
class Neural_Network(object):
  def __init__(self):
    
    self.inputSize = 2
    self.outputSize = 1
    self.hiddenSize = 3

    #weights
    self.W1 = np.random.randn(self.inputSize, self.hiddenSize) 
    self.W2 = np.random.randn(self.hiddenSize, self.outputSize) 

  def forward(self, X):
    
    self.z = np.dot(X, self.W1) 
    self.z2 = self.sigmoid(self.z) 
    self.z3 = np.dot(self.z2, self.W2) 
    o = self.sigmoid(self.z3) 
    return o 

  def sigmoid(self, s):
    return 1/(1+np.exp(-s))

  def sigmoidPrime(self, s):
    return s * (1 - s)

  def backward(self, X, y, o):

    self.o_error = y - o
    self.o_delta = self.o_error*self.sigmoidPrime(o)
    self.z2_error = self.o_delta.dot(self.W2.T)
    self.z2_delta = self.z2_error*self.sigmoidPrime(self.z2)

    self.W1 += X.T.dot(self.z2_delta)
    self.W2 += self.z2.T.dot(self.o_delta) 

  def train (self, X, y):
    o = self.forward(X)
    self.backward(X, y, o)

NN = Neural_Network()
for i in range(100): 
  print(f"Dane wejsciowe:{(X)}")
  print(f"Dane wyjsciowe: {y}")
  print(f"Przewidziane dane wyjsciowe: {(NN.forward(X))}" )
  print(f"Stracone: {(np.mean(np.square(y - NN.forward(X)))) }")
  NN.train(X, y)
# Out:
# 3 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.8052339 ]
#  [0.68275291]
#  [0.80804204]]
# Stracone: 0.017101631692470653
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.81455805]
#  [0.69473967]
#  [0.81672088]]
# Stracone: 0.01459960395997083
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.82265231]
#  [0.70532102]
#  [0.82428432]]
# Stracone: 0.012573569685761113
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.82973777]
#  [0.71472384]
#  [0.83092804]]
# Stracone: 0.010913976755797644
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.83598712]
#  [0.72313033]
#  [0.8368059 ]]
# Stracone: 0.009540360725171575
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.84153678]
#  [0.73068799]
#  [0.84204011]]
# Stracone: 0.008392741274293408
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.84649561]
#  [0.73751716]
#  [0.84672871]]
# Stracone: 0.0074257822043151045
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.85095139]
#  [0.7437168 ]
#  [0.85095113]]
# Stracone: 0.0066047695542489175
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.85497557]
#  [0.74936892]
#  [0.85477228]]
# Stracone: 0.005902801410979388
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.85862682]
#  [0.75454202]
#  [0.85824569]]
# Stracone: 0.005298796429718312
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.86195373]
#  [0.75929366]
#  [0.86141584]]
# Stracone: 0.004776063278421667
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.86499687]
#  [0.76367258]
#  [0.86431999]]
# Stracone: 0.00432125967894192
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.86779034]
#  [0.76772028]
#  [0.86698954]]
# Stracone: 0.003923625651404688
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.87036299]
#  [0.77147233]
#  [0.86945116]]
# Stracone: 0.0035744122079577625
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.87273943]
#  [0.77495935]
#  [0.87172763]]
# Stracone: 0.0032664510519747245
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.87494073]
#  [0.77820789]
#  [0.87383852]]
# Stracone: 0.002993827175036429
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.87698504]
#  [0.78124102]
#  [0.87580073]]
# Stracone: 0.002751627359885371
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.87888811]
#  [0.78407895]
#  [0.87762894]]
# Stracone: 0.0025357452533333524
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.88066363]
#  [0.7867394 ]
#  [0.87933595]]
# Stracone: 0.0023427290075843767
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.88232357]
#  [0.78923801]
#  [0.88093297]]
# Stracone: 0.0021696612471320963
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.88387847]
#  [0.7915886 ]
#  [0.88242987]]
# Stracone: 0.0020140637951355906
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.88533759]
#  [0.79380348]
#  [0.88383538]]
# Stracone: 0.0018738215188566305
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.88670915]
#  [0.79589361]
#  [0.88515722]]
# Stracone: 0.0017471210525465478
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.88800045]
#  [0.79786878]
#  [0.88640227]]
# Stracone: 0.001632401181640392
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.88921799]
#  [0.7997378 ]
#  [0.88757667]]
# Stracone: 0.001528312430494416
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.8903676 ]
#  [0.80150858]
#  [0.88868593]]
# Stracone: 0.0014336839614425164
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89145449]
#  [0.80318827]
#  [0.88973499]]
# Stracone: 0.0013474963180328018
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89248336]
#  [0.80478333]
#  [0.8907283 ]]
# Stracone: 0.0012688588672381182
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89345846]
#  [0.80629961]
#  [0.89166989]]
# Stracone: 0.0011969910410010026
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89438362]
#  [0.80774246]
#  [0.89256339]]
# Stracone: 0.0011312066660751315
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89526231]
#  [0.80911673]
#  [0.89341213]]
# Stracone: 0.001070900816924887
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89609771]
#  [0.81042686]
#  [0.89421911]]
# Stracone: 0.001015538739859013
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89689268]
#  [0.81167692]
#  [0.89498707]]
# Stracone: 0.0009646464853244142
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89764987]
#  [0.81287062]
#  [0.89571853]]
# Stracone: 0.0009178029551299532
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89837167]
#  [0.81401139]
#  [0.89641579]]
# Stracone: 0.0008746331266362401
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89906031]
#  [0.81510238]
#  [0.89708096]]
# Stracone: 0.0008348022599057171
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.8997178 ]
#  [0.81614651]
#  [0.89771598]]
# Stracone: 0.0007980109289464856
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90034601]
#  [0.81714645]
#  [0.89832263]]
# Stracone: 0.0007639907464071061
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90094667]
#  [0.81810469]
#  [0.89890257]]
# Stracone: 0.0007325006738530328
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90152136]
#  [0.81902354]
#  [0.89945733]]
# Stracone: 0.0007033238282119412
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90207156]
#  [0.81990513]
#  [0.89998831]]
# Stracone: 0.0006762647099966037
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90259862]
#  [0.82075144]
#  [0.90049682]]
# Stracone: 0.0006511467911893006
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90310381]
#  [0.82156434]
#  [0.90098407]]
# Stracone: 0.0006278104107420091
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90358831]
#  [0.82234553]
#  [0.90145121]]
# Stracone: 0.0006061109339396196
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.9040532 ]
#  [0.82309664]
#  [0.90189927]]
# Stracone: 0.0005859171387267037
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90449951]
#  [0.82381915]
#  [0.90232924]]
# Stracone: 0.0005671097977826608
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90492818]
#  [0.82451448]
#  [0.90274204]]
# Stracone: 0.0005495804298596824
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.9053401 ]
#  [0.82518395]
#  [0.90313852]]
# Stracone: 0.0005332301978468492
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90573611]
#  [0.82582879]
#  [0.90351948]]
# Stracone: 0.0005179689343305381
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90611697]
#  [0.82645015]
#  [0.90388567]]
# Stracone: 0.0005037142781989109
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90648341]
#  [0.82704913]
#  [0.9042378 ]]
# Stracone: 0.0004903909081786816
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90683613]
#  [0.82762675]
#  [0.90457652]]
# Stracone: 0.00047792986116918743
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90717575]
#  [0.82818398]
#  [0.90490245]]
# Stracone: 0.00046626792491366126
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90750289]
#  [0.82872171]
#  [0.90521619]]
# Stracone: 0.0004553470959703781
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90781811]
#  [0.82924082]
#  [0.90551827]]
# Stracone: 0.0004451140951575962
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90812194]
#  [0.82974211]
#  [0.90580922]]
# Stracone: 0.00043551993368051977
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90841489]
#  [0.83022634]
#  [0.90608953]]
# Stracone: 0.00042651952403354896
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90869743]
#  [0.83069424]
#  [0.90635966]]
# Stracone: 0.00041807133053006675
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90897002]
#  [0.83114649]
#  [0.90662004]]
# Stracone: 0.00041013705496480233
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90923307]
#  [0.83158374]
#  [0.90687108]]
# Stracone: 0.0004026813534757493
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.909487  ]
#  [0.8320066 ]
#  [0.90711318]]
# Stracone: 0.0003956715811584773
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90973218]
#  [0.83241565]
#  [0.90734671]]
# Stracone: 0.0003890775614052439
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90996897]
#  [0.83281145]
#  [0.90757201]]
# Stracone: 0.0003828713773057825
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.91019771]
#  [0.83319453]
#  [0.90778942]]
# Stracone: 0.00037702718276272747
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.91041873]
#  [0.83356538]
#  [0.90799925]]
# Stracone: 0.0003715210312499129
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.91063233]
#  [0.83392448]
#  [0.90820181]]
# Stracone: 0.00036633072038191335
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.91083881]
#  [0.83427227]
#  [0.90839738]]
# Stracone: 0.0003614356506725417
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.91103845]
#  [0.8346092 ]
#  [0.90858623]]
# Stracone: 0.0003568166970437446
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.91123151]
#  [0.83493566]
#  [0.90876862]]
# Stracone: 0.0003524560918068585
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.91141824]
#  [0.83525206]
#  [0.90894479]]
# Stracone: 0.0003483373179794284
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.91159889]
#  [0.83555876]
#  [0.90911497]]
# Stracone: 0.00034444501192488347
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.91177367]
#  [0.83585612]
#  [0.9092794 ]]
# Stracone: 0.0003407648744116771
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.91194282]
#  [0.83614448]
#  [0.90943829]]
# Stracone: 0.0003372835892848371
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.91210654]
#  [0.83642417]
#  [0.90959183]]
# Stracone: 0.00033398874902822
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.91226502]
#  [0.83669549]
#  [0.90974022]]
# Stracone: 0.00033086878657087696
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.91241846]
#  [0.83695874]
#  [0.90988365]]
# Stracone: 0.0003279129127579438
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.91256704]
#  [0.83721421]
#  [0.91002229]]
# Stracone: 0.00032511105896550565
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.91271093]
#  [0.83746217]
#  [0.91015632]]
# Stracone: 0.00032245382439163823
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.9128503 ]
#  [0.83770288]
#  [0.9102859 ]]
# Stracone: 0.000319932427602528
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.9129853 ]
#  [0.83793659]
#  [0.91041117]]
# Stracone: 0.0003175386619543827
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.9131161 ]
#  [0.83816354]
#  [0.9105323 ]]
# Stracone: 0.0003152648545489024
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.91324283]
#  [0.83838396]
#  [0.91064943]]
# Stracone: 0.00031310382841343465
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.91336564]
#  [0.83859806]
#  [0.91076268]]
# Stracone: 0.0003110488676264362
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.91348465]
#  [0.83880607]
#  [0.91087219]]
# Stracone: 0.0003090936851356402
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.9136    ]
#  [0.83900817]
#  [0.91097809]]
# Stracone: 0.0003072323930399659
