# %%
import numpy as np

# %%
X = np.array(([2, 9], [1, 5], [3, 6]), dtype=float)
y = np.array(([92], [86], [89]), dtype=float)

X = X/np.amax(X, axis=0) 
y = y/100

# %%
class Neural_Network(object):
    def __init__(self): 
        self.inputSize = 2
        self.outputSize = 1
        self.hiddenSize = 3        
        #wwagi
        self.W1 = np.random.randn(self.inputSize, self.hiddenSize) 
        self.W2 = np.random.randn(self.hiddenSize, self.outputSize) 

    def forward(self, X):
        self.z = np.dot(X, self.W1) 
        self.z2 = self.sigmoid(self.z) 
        self.z3 = np.dot(self.z2, self.W2) 
        o = self.sigmoid(self.z3) 
        return o 

    def sigmoid(self, s): 
        return 1/(1+np.exp(-s))

    def sigmoidPrime(self, s):
        return s * (1 - s)

    def backward(self, X, y, o):
        self.o_error = y - o
        self.o_delta = self.o_error*self.sigmoidPrime(o)
        self.z2_error = self.o_delta.dot(self.W2.T)
        self.z2_delta = self.z2_error*self.sigmoidPrime(self.z2)

        self.W1 += X.T.dot(self.z2_delta)
        self.W2 += self.z2.T.dot(self.o_delta) 

    def train (self, X, y):
        o = self.forward(X)
        self.backward(X, y, o)

NN = Neural_Network()
for i in range(100): 
    print(f"Dane wejsciowe:{(X)}")
    print(f"Dane wyjsciowe: {y}")
    print(f"Przewidziane dane wyjsciowe: {(NN.forward(X))}" )
    print(f"Stracone: {(np.mean(np.square(y - NN.forward(X)))) }")
    NN.train(X, y)
# Out:
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.70777107]
#  [0.68241263]
#  [0.68821066]]
# Stracone: 0.0390991094398409
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.75033009]
#  [0.72105646]
#  [0.73179659]]
# Stracone: 0.02437383497023012
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.77863999]
#  [0.74731066]
#  [0.76106419]]
# Stracone: 0.01643532825898002
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.79875543]
#  [0.76629465]
#  [0.78200289]]
# Stracone: 0.011714771238919043
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.81378608]
#  [0.78068791]
#  [0.79773006]]
# Stracone: 0.008695182578847717
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.82545351]
#  [0.79199856]
#  [0.80998795]]
# Stracone: 0.006655054475419927
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.83478025]
#  [0.8011354 ]
#  [0.81981893]]
# Stracone: 0.005217609875145971
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.84241043]
#  [0.80867828]
#  [0.82788342]]
# Stracone: 0.004170843279518932
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.84876989]
#  [0.81501493]
#  [0.83462011]]
# Stracone: 0.0033881055891818146
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.8541516 ]
#  [0.82041483]
#  [0.84033205]]
# Stracone: 0.0027899675501912463
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.8587639 ]
#  [0.82507145]
#  [0.84523549]]
# Stracone: 0.002324574814322401
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.8627592 ]
#  [0.82912748]
#  [0.84948907]]
# Stracone: 0.0019569190611411482
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.86625162]
#  [0.83269065]
#  [0.85321195]]
# Stracone: 0.0016626830385653827
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.86932847]
#  [0.8358439 ]
#  [0.85649545]]
# Stracone: 0.0014245586935260955
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.87205768]
#  [0.83865226]
#  [0.85941079]]
# Stracone: 0.0012299640591628474
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.87449296]
#  [0.84116745]
#  [0.86201442]]
# Stracone: 0.0010695826457153624
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.87667741]
#  [0.84343119]
#  [0.86435167]]
# Stracone: 0.0009364031648337393
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.87864597]
#  [0.84547752]
#  [0.86645939]]
# Stracone: 0.0008250728143642875
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.88042736]
#  [0.84733453]
#  [0.86836787]]
# Stracone: 0.0007314523242570228
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.88204536]
#  [0.84902562]
#  [0.87010226]]
# Stracone: 0.0006523039132307136
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.88351987]
#  [0.85057044]
#  [0.87168362]]
# Stracone: 0.0005850686648727761
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.88486768]
#  [0.85198566]
#  [0.87312973]]
# Stracone: 0.0005277052163237913
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.88610304]
#  [0.85328547]
#  [0.87445572]]
# Stracone: 0.0004785712166300126
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.88723815]
#  [0.85448208]
#  [0.87567453]]
# Stracone: 0.00043633509028444045
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.88828352]
#  [0.85558602]
#  [0.87679733]]
# Stracone: 0.0003999095831516527
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.88924824]
#  [0.85660647]
#  [0.87783379]]
# Stracone: 0.0003684011714048675
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89014023]
#  [0.85755141]
#  [0.87879233]]
# Stracone: 0.00034107116284772286
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.8909664 ]
#  [0.85842789]
#  [0.87968035]]
# Stracone: 0.0003173055129804842
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89173286]
#  [0.85924207]
#  [0.88050432]]
# Stracone: 0.00029659120374821206
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89244497]
#  [0.85999946]
#  [0.88126999]]
# Stracone: 0.00027849761184699505
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.8931075 ]
#  [0.86070491]
#  [0.88198243]]
# Stracone: 0.00026266170447015146
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89372468]
#  [0.86136278]
#  [0.88264618]]
# Stracone: 0.0002487761955214505
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89430029]
#  [0.86197696]
#  [0.88326527]]
# Stracone: 0.00023658000954398075
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89483773]
#  [0.86255093]
#  [0.88384333]]
# Stracone: 0.0002258505576603336
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89534003]
#  [0.86308784]
#  [0.88438362]]
# Stracone: 0.0002163974460354084
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89580995]
#  [0.86359053]
#  [0.88488908]]
# Stracone: 0.0002080573241328001
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89624995]
#  [0.86406158]
#  [0.88536236]]
# Stracone: 0.0002006896453436504
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89666229]
#  [0.86450332]
#  [0.88580586]]
# Stracone: 0.00019417316211191066
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.897049  ]
#  [0.86491786]
#  [0.88622177]]
# Stracone: 0.00018840301554450632
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89741193]
#  [0.86530716]
#  [0.88661208]]
# Stracone: 0.00018328830863479988
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89775278]
#  [0.86567298]
#  [0.88697861]]
# Stracone: 0.00017875007480174738
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.8980731 ]
#  [0.86601693]
#  [0.88732302]]
# Stracone: 0.00017471957104420668
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.8983743 ]
#  [0.86634051]
#  [0.88764683]]
# Stracone: 0.0001711368388090057
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89865768]
#  [0.86664508]
#  [0.88795143]]
# Stracone: 0.00016794948655353339
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89892443]
#  [0.8669319 ]
#  [0.88823811]]
# Stracone: 0.00016511165661154832
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89917566]
#  [0.86720212]
#  [0.88850805]]
# Stracone: 0.00016258314584674223
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89941238]
#  [0.86745682]
#  [0.88876234]]
# Stracone: 0.00016032865508490638
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89963553]
#  [0.86769699]
#  [0.88900199]]
# Stracone: 0.0001583171467457084
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89984596]
#  [0.86792355]
#  [0.88922792]]
# Stracone: 0.00015652129367533916
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90004449]
#  [0.86813733]
#  [0.88944101]]
# Stracone: 0.00015491700508712814
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90023185]
#  [0.86833913]
#  [0.88964205]]
# Stracone: 0.0001534830178851111
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90040873]
#  [0.86852969]
#  [0.88983178]]
# Stracone: 0.00015220054358284257
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90057578]
#  [0.86870968]
#  [0.89001089]]
# Stracone: 0.00015105296262065538
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90073359]
#  [0.86887974]
#  [0.89018003]]
# Stracone: 0.0001500255591956287
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90088272]
#  [0.86904046]
#  [0.89033979]]
# Stracone: 0.000149105290802774
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90102368]
#  [0.86919239]
#  [0.89049073]]
# Stracone: 0.0001482805875857187
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90115695]
#  [0.86933605]
#  [0.89063338]]
# Stracone: 0.00014754117734397143
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90128299]
#  [0.86947191]
#  [0.89076821]]
# Stracone: 0.00014687793266917533
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90140222]
#  [0.86960044]
#  [0.89089568]]
# Stracone: 0.0001462827372063791
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90151502]
#  [0.86972204]
#  [0.89101621]]
# Stracone: 0.00014574836847611669
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90162178]
#  [0.86983712]
#  [0.89113021]]
# Stracone: 0.0001452683950633745
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90172283]
#  [0.86994604]
#  [0.89123805]]
# Stracone: 0.00014483708629224333
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.9018185 ]
#  [0.87004915]
#  [0.89134007]]
# Stracone: 0.00014444933276965382
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.9019091 ]
#  [0.87014678]
#  [0.8914366 ]]
# Stracone: 0.00014410057640629504
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.9019949 ]
#  [0.87023923]
#  [0.89152796]]
# Stracone: 0.00014378674871372665
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90207617]
#  [0.87032679]
#  [0.89161442]]
# Stracone: 0.00014350421633962574
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90215317]
#  [0.87040974]
#  [0.89169626]]
# Stracone: 0.00014324973294226506
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90222613]
#  [0.87048831]
#  [0.89177374]]
# Stracone: 0.0001430203966243769
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90229528]
#  [0.87056277]
#  [0.89184709]]
# Stracone: 0.00014281361224886772
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90236082]
#  [0.87063332]
#  [0.89191655]]
# Stracone: 0.00014262705804663696
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90242295]
#  [0.87070018]
#  [0.89198231]]
# Stracone: 0.00014245865600248772
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90248186]
#  [0.87076355]
#  [0.8920446 ]]
# Stracone: 0.00014230654557041112
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90253772]
#  [0.87082362]
#  [0.89210358]]
# Stracone: 0.0001421690603259412
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90259069]
#  [0.87088057]
#  [0.89215945]]
# Stracone: 0.00014204470721220432
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90264093]
#  [0.87093456]
#  [0.89221236]]
# Stracone: 0.000141932148078679
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90268859]
#  [0.87098576]
#  [0.89226248]]
# Stracone: 0.00014183018324845118
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90273381]
#  [0.8710343 ]
#  [0.89230996]]
# Stracone: 0.000141737736881886
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90277671]
#  [0.87108034]
#  [0.89235493]]
# Stracone: 0.00014165384393248284
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90281741]
#  [0.87112401]
#  [0.89239753]]
# Stracone: 0.00014157763851507677
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90285605]
#  [0.87116542]
#  [0.89243789]]
# Stracone: 0.00014150834352782724
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90289271]
#  [0.8712047 ]
#  [0.89247612]]
# Stracone: 0.0001414452613880758
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90292752]
#  [0.87124197]
#  [0.89251234]]
# Stracone: 0.00014138776575844164
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90296056]
#  [0.87127732]
#  [0.89254665]]
# Stracone: 0.0001413352941538797
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90299193]
#  [0.87131086]
#  [0.89257916]]
# Stracone: 0.00014128734133293534
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90302172]
#  [0.87134268]
#  [0.89260995]]
# Stracone: 0.00014124345338755289
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90305   ]
#  [0.87137288]
#  [0.89263911]]
# Stracone: 0.00014120322245543969
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90307687]
#  [0.87140153]
#  [0.89266674]]
# Stracone: 0.00014116628198763409
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90310238]
#  [0.87142872]
#  [0.89269292]]
# Stracone: 0.00014113230251143805
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90312662]
#  [0.87145453]
#  [0.89271771]]
# Stracone: 0.00014110098783551251
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90314965]
#  [0.87147902]
#  [0.89274119]]
# Stracone: 0.00014107207164994865
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90317153]
#  [0.87150226]
#  [0.89276342]]
# Stracone: 0.00014104531447920436
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90319232]
#  [0.87152432]
#  [0.89278448]]
# Stracone: 0.00014102050095048598
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90321208]
#  [0.87154527]
#  [0.89280443]]
# Stracone: 0.0001409974373442378
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90323086]
#  [0.87156515]
#  [0.89282331]]
# Stracone: 0.00014097594939700418
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90324871]
#  [0.87158402]
#  [0.89284119]]
# Stracone: 0.00014095588033019663
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90326568]
#  [0.87160193]
#  [0.89285812]]
# Stracone: 0.00014093708908104142
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90328181]
#  [0.87161894]
#  [0.89287414]]
# Stracone: 0.00014091944871469394
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90329716]
#  [0.87163509]
#  [0.89288931]]
# Stracone: 0.00014090284499857476
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90331175]
#  [0.87165043]
#  [0.89290366]]
# Stracone: 0.00014088717512216202
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90332563]
#  [0.87166499]
#  [0.89291725]]
# Stracone: 0.00014087234654710127
