# %%
import numpy as np

# %%
X = np.array(([2, 9], [1, 5], [3, 6]), dtype=float)

X = X/np.amax(X, axis=0) 
y = y/100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a374e4576a56> in <module>
#       2
#       3 X = X/np.amax(X, axis=0)
# ----> 4 y = y/100
#
# NameError: name 'y' is not defined

# %%
class Neural_Network(object):
    def __init__(self): 
        self.inputSize = 2
        self.outputSize = 1
        self.hiddenSize = 3        
        #wwagi
        self.W1 = np.random.randn(self.inputSize, self.hiddenSize) 
        self.W2 = np.random.randn(self.hiddenSize, self.outputSize) 

    def forward(self, X):
        self.z = np.dot(X, self.W1) 
        self.z2 = self.sigmoid(self.z) 
        self.z3 = np.dot(self.z2, self.W2) 
        o = self.sigmoid(self.z3) 
        return o 

    def sigmoid(self, s): 
        return 1/(1+np.exp(-s))

    def sigmoidPrime(self, s):
        return s * (1 - s)

    def backward(self, X, y, o):
        self.o_error = y - o
        self.o_delta = self.o_error*self.sigmoidPrime(o)
        self.z2_error = self.o_delta.dot(self.W2.T)
        self.z2_delta = self.z2_error*self.sigmoidPrime(self.z2)

        self.W1 += X.T.dot(self.z2_delta)
        self.W2 += self.z2.T.dot(self.o_delta) 

    def train (self, X, y):
        o = self.forward(X)
        self.backward(X, y, o)

NN = Neural_Network()
for i in range(100): 
    print(f"Dane wejsciowe:{(X)}")
    print(f"Dane wyjsciowe: {y}")
    print(f"Przewidziane dane wyjsciowe: {(NN.forward(X))}" )
    print(f"Stracone: {(np.mean(np.square(y - NN.forward(X)))) }")
    NN.train(X, y)
# Out:
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.18921015]
#  [0.18531167]
#  [0.19044872]]
# Stracone: 0.49287671809888867
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.24634402]
#  [0.23078285]
#  [0.24577571]]
# Stracone: 0.42158384880101707
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.31137417]
#  [0.28346297]
#  [0.30791577]]
# Stracone: 0.3472141316866411
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.37776717]
#  [0.33943286]
#  [0.37070897]]
# Stracone: 0.2782232548875511
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.44036036]
#  [0.39462069]
#  [0.42958865]]
# Stracone: 0.21953689572896443
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.49707066]
#  [0.44638507]
#  [0.48293845]]
# Stracone: 0.1718818816759388
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.54762985]
#  [0.49347694]
#  [0.53074937]]
# Stracone: 0.13401989887617638
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.59222835]
#  [0.53543496]
#  [0.57331335]]
# Stracone: 0.10435571883374374
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.63109401]
#  [0.57221807]
#  [0.61084158]]
# Stracone: 0.08140484450826548
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.6645405 ]
#  [0.60406627]
#  [0.64354817]]
# Stracone: 0.06383337728432177
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.69303676]
#  [0.63141839]
#  [0.67176376]]
# Stracone: 0.05046297386751362
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.71717733]
#  [0.65482237]
#  [0.69594546]]
# Stracone: 0.04029735167740052
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.73760102]
#  [0.67485075]
#  [0.71661806]]
# Stracone: 0.03253697687025269
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.75491805]
#  [0.6920414 ]
#  [0.73430732]]
# Stracone: 0.026567451169456736
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.76966856]
#  [0.70686754]
#  [0.74949533]]
# Stracone: 0.02193021812921442
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.78230867]
#  [0.71972925]
#  [0.76260042]]
# Stracone: 0.018288479713522075
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.79321318]
#  [0.73095712]
#  [0.77397377]]
# Stracone: 0.015396350098186662
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.8026856 ]
#  [0.74082114]
#  [0.78390479]]
# Stracone: 0.01307415398717946
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.81097027]
#  [0.74954075]
#  [0.79262981]]
# Stracone: 0.01118989332939929
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.81826365]
#  [0.75729431]
#  [0.80034121]]
# Stracone: 0.009645813714679237
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.82472413]
#  [0.76422716]
#  [0.80719567]]
# Stracone: 0.00836882842700785
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.83047997]
#  [0.77045826]
#  [0.81332119]]
# Stracone: 0.007303732942073228
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.8356356 ]
#  [0.77608554]
#  [0.8188228 ]]
# Stracone: 0.006408393823427563
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.84027661]
#  [0.78119006]
#  [0.82378717]]
# Stracone: 0.005650321742166418
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.84447356]
#  [0.78583936]
#  [0.82828618]]
# Stracone: 0.005004213216683025
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.84828506]
#  [0.79009004]
#  [0.83237986]]
# Stracone: 0.004450172354958097
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.85176007]
#  [0.79398984]
#  [0.83611857]]
# Stracone: 0.003972412695737471
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.85493976]
#  [0.79757928]
#  [0.83954487]]
# Stracone: 0.0035583005461334353
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.85785897]
#  [0.8008929 ]
#  [0.84269489]]
# Stracone: 0.003197643276196274
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.86054733]
#  [0.80396036]
#  [0.8455995 ]]
# Stracone: 0.00288215488979946
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.86303022]
#  [0.80680722]
#  [0.84828519]]
# Stracone: 0.0026050510583433997
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.86532945]
#  [0.80945563]
#  [0.8507748 ]]
# Stracone: 0.0023607395575407225
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.86746388]
#  [0.81192489]
#  [0.85308815]]
# Stracone: 0.002144581635252992
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.86944989]
#  [0.81423186]
#  [0.8552425 ]]
# Stracone: 0.0019527065736622596
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.87130178]
#  [0.81639137]
#  [0.85725294]]
# Stracone: 0.0017818664792404904
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.87303208]
#  [0.81841647]
#  [0.8591327 ]]
# Stracone: 0.0016293217406117327
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.87465181]
#  [0.82031873]
#  [0.86089348]]
# Stracone: 0.0014927500476291714
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.87617071]
#  [0.82210843]
#  [0.86254562]]
# Stracone: 0.001370173646279279
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.8775974 ]
#  [0.82379471]
#  [0.86409828]]
# Stracone: 0.0012599008079292248
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.87893956]
#  [0.82538577]
#  [0.86555965]]
# Stracone: 0.00116047845344778
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.88020403]
#  [0.82688896]
#  [0.86693703]]
# Stracone: 0.0010706535879490505
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.88139696]
#  [0.82831087]
#  [0.86823698]]
# Stracone: 0.0009893417375928422
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.88252383]
#  [0.82965747]
#  [0.86946538]]
# Stracone: 0.0009156009839656555
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.88358962]
#  [0.83093414]
#  [0.87062755]]
# Stracone: 0.000848610498491307
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.88459879]
#  [0.83214579]
#  [0.87172829]]
# Stracone: 0.0007876527139903598
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.8855554 ]
#  [0.83329684]
#  [0.87277194]]
# Stracone: 0.0007320984510776184
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.88646311]
#  [0.83439136]
#  [0.87376246]]
# Stracone: 0.0006813944568794806
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.88732527]
#  [0.83543303]
#  [0.87470344]]
# Stracone: 0.000635052922414519
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.88814493]
#  [0.83642523]
#  [0.87559816]]
# Stracone: 0.0005926426302339912
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.88892487]
#  [0.83737108]
#  [0.87644963]]
# Stracone: 0.00055378145104626
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.88966763]
#  [0.83827341]
#  [0.87726058]]
# Stracone: 0.0005181299611807598
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89037555]
#  [0.83913486]
#  [0.87803356]]
# Stracone: 0.00048538599501100373
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89105078]
#  [0.83995782]
#  [0.87877086]]
# Stracone: 0.0004552799802382081
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89169528]
#  [0.84074455]
#  [0.87947463]]
# Stracone: 0.00042757093106366085
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89231089]
#  [0.84149709]
#  [0.88014684]]
# Stracone: 0.0004020429961586755
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89289928]
#  [0.84221737]
#  [0.88078932]]
# Stracone: 0.00037850247606452614
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89346201]
#  [0.84290716]
#  [0.88140374]]
# Stracone: 0.0003567752390715394
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89400052]
#  [0.84356811]
#  [0.88199168]]
# Stracone: 0.0003367044763995301
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89451614]
#  [0.84420174]
#  [0.88255458]]
# Stracone: 0.0003181487471528032
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89501012]
#  [0.8448095 ]
#  [0.8830938 ]]
# Stracone: 0.0003009802714636967
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89548362]
#  [0.84539271]
#  [0.88361058]]
# Stracone: 0.0002850834367957608
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89593771]
#  [0.84595263]
#  [0.88410611]]
# Stracone: 0.00027035348781039476
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.8963734 ]
#  [0.8464904 ]
#  [0.88458147]]
# Stracone: 0.00025669537471736264
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89679162]
#  [0.84700714]
#  [0.88503768]]
# Stracone: 0.00024402273879622061
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89719325]
#  [0.84750384]
#  [0.8854757 ]]
# Stracone: 0.00023225701692687845
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89757911]
#  [0.84798149]
#  [0.88589643]]
# Stracone: 0.0002213266496116459
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89794998]
#  [0.84844097]
#  [0.88630071]]
# Stracone: 0.00021116637919596862
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89830657]
#  [0.84888314]
#  [0.88668931]]
# Stracone: 0.00020171662687297064
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89864957]
#  [0.84930879]
#  [0.88706299]]
# Stracone: 0.00019292293864553475
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89897961]
#  [0.84971867]
#  [0.88742244]]
# Stracone: 0.00018473549176783197
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89929728]
#  [0.8501135 ]
#  [0.8877683 ]]
# Stracone: 0.00017710865433451033
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89960316]
#  [0.85049393]
#  [0.88810121]]
# Stracone: 0.00017000059166359544
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.89989778]
#  [0.8508606 ]
#  [0.88842174]]
# Stracone: 0.00016337291395456172
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90018164]
#  [0.85121411]
#  [0.88873043]]
# Stracone: 0.00015719036041898332
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90045521]
#  [0.85155502]
#  [0.88902782]]
# Stracone: 0.00015142051569570186
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90071895]
#  [0.85188387]
#  [0.88931439]]
# Stracone: 0.00014603355489144342
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90097327]
#  [0.85220116]
#  [0.8895906 ]]
# Stracone: 0.00014100201404387312
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90121858]
#  [0.85250737]
#  [0.88985689]]
# Stracone: 0.00013630058319817452
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90145526]
#  [0.85280296]
#  [0.89011369]]
# Stracone: 0.0001319059196295281
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90168367]
#  [0.85308836]
#  [0.89036138]]
# Stracone: 0.00012779647903991793
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90190414]
#  [0.85336399]
#  [0.89060034]]
# Stracone: 0.0001239523628149699
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90211702]
#  [0.85363022]
#  [0.89083092]]
# Stracone: 0.00012035517965071787
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.9023226 ]
#  [0.85388744]
#  [0.89105347]]
# Stracone: 0.00011698792005554649
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90252117]
#  [0.854136  ]
#  [0.8912683 ]]
# Stracone: 0.00011383484240347874
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90271302]
#  [0.85437623]
#  [0.89147572]]
# Stracone: 0.00011088136936452838
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90289842]
#  [0.85460846]
#  [0.89167603]]
# Stracone: 0.00010811399366886496
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.9030776 ]
#  [0.85483299]
#  [0.89186949]]
# Stracone: 0.00010552019227685822
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90325082]
#  [0.85505011]
#  [0.89205637]]
# Stracone: 0.00010308834812819112
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.9034183 ]
#  [0.85526011]
#  [0.89223693]]
# Stracone: 0.00010080767873265467
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90358027]
#  [0.85546325]
#  [0.89241141]]
# Stracone: 9.86681709438314e-05
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90373693]
#  [0.85565978]
#  [0.89258003]]
# Stracone: 9.666052132656368e-05
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90388847]
#  [0.85584995]
#  [0.89274301]]
# Stracone: 9.477608159059801e-05
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.9040351 ]
#  [0.85603399]
#  [0.89290057]]
# Stracone: 9.300680861740656e-05
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90417699]
#  [0.85621213]
#  [0.89305289]]
# Stracone: 9.134521865553979e-05
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90431432]
#  [0.85638457]
#  [0.89320019]]
# Stracone: 8.978434530294426e-05
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90444725]
#  [0.85655151]
#  [0.89334263]]
# Stracone: 8.83177009328545e-05
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90457595]
#  [0.85671317]
#  [0.89348039]]
# Stracone: 8.6939241254023e-05
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90470056]
#  [0.85686971]
#  [0.89361364]]
# Stracone: 8.564333272645402e-05
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.90482123]
#  [0.85702133]
#  [0.89374254]]
# Stracone: 8.442472258084117e-05
# Dane wejsciowe:[[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Dane wyjsciowe: [[0.92]
#  [0.86]
#  [0.89]]
# Przewidziane dane wyjsciowe: [[0.9049381 ]
#  [0.85716819]
#  [0.89386725]]
# Stracone: 8.327851121434775e-05
