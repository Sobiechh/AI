# %%
# !pip install neurolab
# Out:
# Collecting neurolab
#   Downloading neurolab-0.3.5.tar.gz (645 kB)
# Building wheels for collected packages: neurolab
#   Building wheel for neurolab (setup.py): started
#   Building wheel for neurolab (setup.py): finished with status 'done'
#   Created wheel for neurolab: filename=neurolab-0.3.5-py3-none-any.whl size=22186 sha256=ea8d64f00981ac354348e2552cecd4bcc28381b50a6435365d4c2276ca673a39
#   Stored in directory: c:\users\piotr\appdata\local\pip\cache\wheels\3e\07\63\e3d6e066089d7186465184a6f9a1884471485f38beef1edeaa
# Successfully built neurolab
# Installing collected packages: neurolab
# Successfully installed neurolab-0.3.5

# %%
import numpy as np
import neurolab as nl
import numpy.random as rand
import pylab as pl

# %%
#Tworzymy zbiór danych
#Ustalamy środki naszych klas
center = np.array([[0.2, 0.2], [0.4, 0.4], [0.7, 0.3], [0.2, 0.5]])
rand_norm = 0.05 * rand.randn(100, 4, 2)
#dane uczące
inp = np.array([center + r for r in rand_norm])
inp.shape = (100 * 4, 2)
rand.shuffle(inp)

#Tworzymy dwa wejścia i 4 neurony
net = nl.net.newc([[0.0, 1.0],[0.0, 1.0]], 4)
#Uczymy sieć zgodnie z algortmem Winner Take All
error = net.train(inp, epochs=200, show=20)

#Wynik do wykrsu
w = net.layers[0].np['w']
pl.plot(inp[:,0], inp[:,1], '.', \
        center[:,0], center[:, 1] , 'yv', \
        w[:,0], w[:,1], 'p')
pl.legend(['Obiekty uczace', 'RZeczywisty srodek klasy',
           'Nauczon srodek klasy'])
pl.show()
# Out:
# Epoch: 20; Error: 32.97261127646898;
# Epoch: 40; Error: 32.33349866602666;
# Epoch: 60; Error: 32.30951606235275;
# Epoch: 80; Error: 32.314862574668695;
# Epoch: 100; Error: 32.31603629067522;
# Epoch: 120; Error: 32.31620908377765;
# Epoch: 140; Error: 32.316234700029455;
# Epoch: 160; Error: 32.31623853119794;
# Epoch: 180; Error: 32.316239110048315;
# Epoch: 200; Error: 32.31623919849895;
# The maximum number of train epochs is reached
